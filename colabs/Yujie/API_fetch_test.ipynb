# %% [markdown]
# <a href="https://colab.research.google.com/github/chyj0805/Project_2/blob/Yujie-branch/colabs/Yujie/API_fetch_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd
import os
from dotenv import load_dotenv

# Load the environment variable file
load_dotenv()

# Get the API key
api_key = os.environ.get("ALPHA_VANTAGE_API_KEY")

if api_key is None:
    raise ValueError("Alpha Vantage API key is not set in the environment.")

# After loading the environment variables
print("API Key from env:", os.environ.get("ALPHA_VANTAGE_API_KEY"))
# Out:
# API Key from env: 4FHTO2GAT3NL1EZ8

# %%
test_url = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey={api_key}"
response = requests.get(test_url)
print("Response:", response.json())
# Out:
# Response: {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-08-25 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-08-25 19:55:00': {'1. open': '145.3000', '2. high': '145.3400', '3. low': '145.2500', '4. close': '145.2500', '5. volume': '101'}, '2023-08-25 19:50:00': {'1. open': '145.2500', '2. high': '145.2500', '3. low': '145.2500', '4. close': '145.2500', '5. volume': '20'}, '2023-08-25 19:30:00': {'1. open': '145.3200', '2. high': '145.3400', '3. low': '145.3000', '4. close': '145.3400', '5. volume': '3'}, '2023-08-25 19:25:00': {'1. open': '145.2500', '2. high': '145.2500', '3. low': '145.2500', '4. close': '145.2500', '5. volume': '2'}, '2023-08-25 19:20:00': {'1. open': '145.3000', '2. high': '145.3400', '3. low': '145.3000', '4. close': '145.3400', '5. volume': '851'}, '2023-08-25 19:15:00': {'1. open': '145.2500'
# ...

# %%
df_IYE = pd.read_csv('IYE_historical_data.csv')
df_IYE
# Out:
#             Date   Open   High    Low  Close  Volume
# 0     2000-06-16  51.61  51.78  51.55  51.77    2000
# 1     2000-06-19  51.53  51.53  50.63  50.63    2400
# 2     2000-06-20  50.11  50.11  49.78  49.78    1000
# 3     2000-06-21  50.44  51.70  50.44  51.67    3200
# 4     2000-06-22  51.92  51.92  50.52  50.53    2100
# ...          ...    ...    ...    ...    ...     ...
# 5829  2023-08-18  46.02  46.77  45.92  46.71  357874
# 5830  2023-08-21  46.91  47.12  46.17  46.48  435015
# 5831  2023-08-22  46.57  46.68  46.10  46.12  637860
# 5832  2023-08-23  45.71  46.05  45.28  46.00  449799
# 5833  2023-08-24  45.61  46.10  45.55  45.59  417455
#
# [5834 rows x 6 columns]

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={api_key}'
r = requests.get(url)
data = r.json()
data
# Out:
# {'items': '50',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': 'Weekly Roundup',
#    'url': 'https://aap.thestreet.com/story/16131864/1/weekly-roundup.html',
#    'time_published': '20230825T220100',
#    'authors': [],
#    'summary': "Stocks staged a late comeback this week after Fed Chair Jerome Powell's comments at Jackson Hole that were hawkish -- but which many interpreted as not so much. The collective move in stocks over the last month, however, has been negative, with the S&P 500 shedding roughly 4%, while the Nasdaq ...",
#    'banner_image': 'https://s.thestreet.com/files/tsc/v2008/photos/contrib/uploads/c4ea1b1a-4382-11ee-92a9-97cb2322925b.png',
#    'source': 'The Street',
#    'category_within_source': 'GoogleRSS',
# ...

# %%
# Replace 'YOUR_API_KEY' with the API key you got from Alphavantage
api_key = os.environ.get("ALPHA_VANTAGE_API_KEY")

# Define the stock symbol and the interval for the VWAP
symbol = 'IBM'
interval = '15min'

# Construct the API URL
url = f'https://www.alphavantage.co/query?function=VWAP&symbol={symbol}&interval={interval}&apikey={api_key}'

# Make the API request
response = requests.get(url)
data = response.json()

# Pretty print the JSON data (you can also parse it and use it as per your needs)
print(json.dumps(data, indent=4))
# Out:
# {
#     "Meta Data": {
#         "1: Symbol": "IBM",
#         "2: Indicator": "Volume Weighted Average Price (VWAP)",
#         "3: Last Refreshed": "2023-08-25 19:45:00",
#         "4: Interval": "15min",
#         "5: Time Zone": "US/Eastern"
#     },
#     "Technical Analysis: VWAP": {
#         "2023-08-25 19:45": {
#             "VWAP": "145.0488"
#         },
#         "2023-08-25 19:30": {
#             "VWAP": "145.0488"
#         },
#         "2023-08-25 19:15": {
#             "VWAP": "145.0488"
#         },
#         "2023-08-25 19:00": {
#             "VWAP": "145.0487"
#         },
#         "2023-08-25 18:45": {
#             "VWAP": "145.0214"
#         },
#         "2023-08-25 18:30": {
#             "VWAP": "145.0214"
#         },
#         "2023-08-25 18:15": {
#             "VWAP": "144.9885"
#         },
#         "2023-08-25 18:00": {
#             "VWAP": "144.9885"
#         },
#         "2023-08-25 17:45": {
#             "VWAP": "144.9885"
#         },
# ...
